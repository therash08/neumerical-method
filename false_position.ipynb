# %%
import math

# %%
def f(x):
  return x**2-2

# %%
def false_pos(xl, xu):
    if f(xl) * f(xu) > 0:
        print("invalid")
        return None
    
    prev_xr = 0
    it = 1

    print("it\t\t xl\t xu\t xr\t f(xr)")
    print("-"* 50)

    while True:
        xr = xu - (f(xu)* (xl-xu)/f(xl)-f(xu))
        print(f"{it}\t{xl:.6f}\t{xu:.6f}\t{xr:.6f}\t{f(xr):.6f}")

        if prev_xr == xr:
            break
        if f(xl) * f(xr) > 0:
            xl = xr
        else:
            xu = xr

        prev_xr = xr
        it+= 1

    return xr

# %%
xl = 1
xu = 2
root = bisection(xl, xu)
print(root)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 xl = 1
#       2 xu = 2
# ----> 3 root = bisection(xl, xu)
#       4 print(root)
#
# NameError: name 'bisection' is not defined
