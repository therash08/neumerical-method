# %%
import math

# %%
def f(x):
    return math.sqrt(x+6)

# %%
x0 = 0
es = 0.05
while True:
    x1 = f(x0)
    ea = (abs(x1-x0)/x1)
    print (x1, ea)
    if ea < es:
        break
    x0 = x1
# Out:
# 2.449489742783178 1.0
# 2.9068006025152773 0.15732446846762888
# 2.984426343958798 0.026010272158551992
